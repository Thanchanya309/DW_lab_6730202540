# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanchanya309/DW_lab_6730202540/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("673020254-0");
# Out:
# 673020254-0
